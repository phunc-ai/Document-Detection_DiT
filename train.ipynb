# %%
# !nvidia-smi
# Out:
# Sat Apr 30 02:25:32 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !unzip "/content/drive/MyDrive/DiT/dataset/dataset_vi.zip" -d "/content/"

# %%
# !pip install -q torch==1.10.0+cu111 torchvision==0.11.0+cu111 torchaudio==0.10.0 -f https://download.pytorch.org/whl/torch_stable.html

# %%
import torch

torch.__version__
# Out:
# '1.10.0+cu111'

# %%
# !pip install -q detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu111/torch1.10/index.html

# %%
# %cd /content/drive/MyDrive/DiT/unilm/dit/
# !pip install -r requirements.txt
# !pip install shapely

# %%
# %cd /content/drive/MyDrive/DiT/unilm/apex
# !pip install -v --disable-pip-version-check --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./

# %%
# %cd /content/drive/MyDrive/DiT/unilm/dit/object_detection
# Out:
# /content/drive/MyDrive/DiT/unilm/dit/object_detection

# %%
# !python train_net.py --config-file publaynet_configs/cascade/cascade_dit_base.yaml \
        --num-gpus 1 \
        --resume \
        OUTPUT_DIR /content/drive/MyDrive/DiT/experiments/output_4 \
        MODEL.WEIGHTS /content/drive/MyDrive/DiT/pretrained/dit-base-224-p16-500k-62d53a.pth \
# Out:
# /usr/local/lib/python3.7/dist-packages/apex/pyprof/__init__.py:5: FutureWarning: pyprof will be removed by the end of June, 2022
#   warnings.warn("pyprof will be removed by the end of June, 2022", FutureWarning)
# Command Line Args: Namespace(config_file='publaynet_configs/cascade/cascade_dit_base.yaml', debug=False, dist_url='tcp://127.0.0.1:49152', eval_only=False, machine_rank=0, num_gpus=1, num_machines=1, opts=['OUTPUT_DIR', '/content/drive/MyDrive/DiT/experiments/output_4', 'MODEL.WEIGHTS', '/content/drive/MyDrive/DiT/pretrained/dit-base-224-p16-500k-62d53a.pth'], resume=True)
# [04/30 03:31:59 detectron2]: Rank of current process: 0. World size: 1
# [04/30 03:32:00 detectron2]: Environment info:
# ----------------------  ----------------------------------------------------------------
# sys.platform            linux
# Python                  3.7.13 (default, Apr 24 2022, 01:04:09) [GCC 7.5.0]
# numpy                   1.21.6
# ...

# %%
# !python train_net.py --config-file publaynet_configs/cascade/cascade_dit_base.yaml \
    --eval-only \
    --num-gpus 1 \
    --resume \
    OUTPUT_DIR /content/drive/MyDrive/DiT/experiments/output_4
# Out:
# /usr/local/lib/python3.7/dist-packages/apex/pyprof/__init__.py:5: FutureWarning: pyprof will be removed by the end of June, 2022
#   warnings.warn("pyprof will be removed by the end of June, 2022", FutureWarning)
# Command Line Args: Namespace(config_file='publaynet_configs/cascade/cascade_dit_base.yaml', debug=False, dist_url='tcp://127.0.0.1:49152', eval_only=True, machine_rank=0, num_gpus=1, num_machines=1, opts=['OUTPUT_DIR', '/content/drive/MyDrive/DiT/experiments/output_4'], resume=True)
# [04/30 08:42:50 detectron2]: Rank of current process: 0. World size: 1
# [04/30 08:42:51 detectron2]: Environment info:
# ----------------------  ----------------------------------------------------------------
# sys.platform            linux
# Python                  3.7.13 (default, Apr 24 2022, 01:04:09) [GCC 7.5.0]
# numpy                   1.21.6
# detectron2              0.6 @/usr/local/lib/python3.7/dist-packages/detectron2
# Compiler                GCC 7.3
# ...

# %%
# !python inference.py \
--image_path '/content/dataset_vi/train/Luanan_ Ngo Hoang Huy-144.jpg' \
--output_file_name /content/output.jpg \
--config-file publaynet_configs/cascade/cascade_dit_base.yaml \
--opts MODEL.WEIGHTS /content/drive/MyDrive/DiT/experiments/output_4/model_final.pth
# Out:
# /usr/local/lib/python3.7/dist-packages/apex/pyprof/__init__.py:5: FutureWarning: pyprof will be removed by the end of June, 2022
#   warnings.warn("pyprof will be removed by the end of June, 2022", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/detectron2/structures/image_list.py:88: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_size = (max_size + (stride - 1)) // stride * stride
# ...
